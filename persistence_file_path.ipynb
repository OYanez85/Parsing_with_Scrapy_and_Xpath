# %% [markdown]
# # Persistence and Efficency
# You now might be aware of some of the problems with parsing several pages and how that can quicly get out of hand. While parsing, you might chose to persist the collected data, so that it can be analyzed and cleaned later.
# Parsing, retrieving, saving, and cleaning data are all separate actions, and you shouldn't try to work with data while collecting. In this notebook you'll practice further parsing techniques along with persistency, both for JSON and CSV formats as well as using SQL and a database.
#
# Start by loading one of the available HTML files into the `scrapy` library
#
# **Note**: This notebook relies on several dependencies that must be pre-installed in your environment. If you haven't done so, please run the following command in your terminal or command prompt:
# ```bash
# python3 -m venv venv
# venv/bin/pip install -r requirements.txt
# ```

# %%
import scrapy
import os
current_dir = os.path.abspath('')
url = os.path.join(current_dir, "html/1994_World_Junior_Championships_in_Athletics_–_Men's_high_jump")
with open(url) as _f:
    url_data = _f.read()

response = scrapy.http.TextResponse(url, body=url_data, encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       3 current_dir = os.path.abspath('')
#       4 url = os.path.join(current_dir, "html/1992_World_Junior_Championships_in_Athletics_–_Men's_high_jump")
# ----> 5 with open(url) as _f:
#       6     url_data = _f.read()
#       8 response = scrapy.http.TextResponse(url, body=url_data, encoding='utf-8')
#
# File c:\Users\oscar\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: "c:\\Users\\oscar\\OneDrive\\Oscar\\Master_Data_Science_AI_Nuclio_School\\Recursos _Ejercicios_de_limpieza_y_preprocesamiento_20240318\\Clase_Web_scraping_V4\\Coursera_Webscrapping\\Files\\Files\\home\\jovyan\\work\\scrapy-xpath\\html/1992_World_Junior_Championships_in_Athletics_–_Men's_high_jump"

# %%
import scrapy
import os

# Directly using the new path provided
file_path = r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1992_World_Junior_Championships_in_Athletics_–_Men's_high_jump";

try:
    with open(file_path, 'r', encoding='utf-8') as _f:
        url_data = _f.read()

    # Since this is a local file, using a placeholder URL in the response object
    response = scrapy.http.TextResponse(url='file://' + file_path, body=url_data.encode('utf-8'), encoding='utf-8')
    print("File loaded successfully.")
except FileNotFoundError:
    print(f"File not found: {file_path}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# File loaded successfully.

# %%
import scrapy
import os

# List of file paths
file_paths = [
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1992_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1994_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1996_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1998_World_Junior_Championships_in_Athletics_–_Men's_high_jump"
]

for file_path in file_paths:
    try:
        with open(file_path, 'r', encoding='utf-8') as _f:
            url_data = _f.read()

        # Since this is a local file, using a placeholder URL in the response object
        response = scrapy.http.TextResponse(url='file://' + file_path, body=url_data.encode('utf-8'), encoding='utf-8')
        print(f"File loaded successfully: {file_path}")
    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except Exception as e:
        print(f"An error occurred with {file_path}: {e}")
# Out:
# File loaded successfully: C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1992_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# File loaded successfully: C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1994_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# File loaded successfully: C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1996_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# File loaded successfully: C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1998_World_Junior_Championships_in_Athletics_–_Men's_high_jump

# %%
# Make sure that the interesting data is available 
table = response.xpath('//table')[1].xpath('tbody')
for tr in table.xpath('tr'):
    print(tr.xpath('td/b/text()').extract()[0],
          tr.xpath('td/a/text()').extract()[0]
    )
# Out:
# Gold Alfredo Deza
# Silver Yin Xueli
# Bronze Aleksandr Veryutin

# %% [markdown]
# This interaction with `scrapy` in a Jupyter Notebook is useful because you don't need to run the special shell and you also don't need to run the whole spider. Once you learn what you need to do here, you can adapat the spider to persist data.
# First, start by persisting data as JSON. To do this, you will need to keep the information in a Python data structure like a dictionary, and then load it as a JSON object, and finally, save it to a file.

# %%
scrapped_data = {}
for tr in table.xpath('tr'):
    medal = tr.xpath('td/b/text()').extract()[0]
    athlete = tr.xpath('td/a/text()').extract()[0]
    scrapped_data[medal] = athlete

scrapped_data
# Out:
# {'Gold': 'Alfredo Deza', 'Silver': 'Yin Xueli', 'Bronze': 'Aleksandr Veryutin'}

# %%
import json

# You can convert Python into JSON first, but there is no need if you use `json.dump()`
# as shown next
json_data = json.dumps(scrapped_data)

# Persist it in a file:
with open("all_results.json", "w") as _f:
    # use dump() with the Python dictionary directly. 
    # the conversion is done on the fly
    json.dump(scrapped_data, _f)

# %% [markdown]
# Now that you can persist the scrapped data as JSON, you can also use CSV. This is specially useful if you want to to some data science operations. Although you can use an advanced library like Pandas for this, you can use the standard library CSV module from Python.

# %%
# construct the data first

column_names = ["Medal", "Athlete"]
rows = []

for tr in table.xpath('tr'):
    medal = tr.xpath('td/b/text()').extract()[0]
    athlete = tr.xpath('td/a/text()').extract()[0]
    rows.append([medal, athlete])

# %%
# Now persist it to disk
import csv

with open("results.csv", "w") as _f:
    writer = csv.writer(_f)

    # write the column names
    writer.writerow(column_names)

    # now write the rows
    writer.writerows(rows)

# %% [markdown]
# Finally, you can persist data to a database. Unlike the JSON and CSV approach, using a database is much more memory efficient. This is the principal reason why you want to use a database instead of a file on disk. Imagine capturing 10GB of data. This could potentially mean that you need 10GB of available memory to hold onto that data before saving it to disk.
# By using a database, you can save the data as the data is gathered.
#
# For the next cells, use a SQLite database to persist the data. Create the file-based database and the table needed.

# %%
import sqlite3
connection = sqlite3.connect("1992_results.db")
db_table = 'CREATE TABLE results (id integer primary key, medal TEXT, athlete TEXT)'
cursor = connection.cursor()
cursor.execute(db_table)
connection.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[41], line 5
#       3 db_table = 'CREATE TABLE results (id integer primary key, medal TEXT, athlete TEXT)'
#       4 cursor = connection.cursor()
# ----> 5 cursor.execute(db_table)
#       6 connection.commit()
#
# OperationalError: table results already exists

# %%
# Now it is time to persist the data. Open the connection again
connection = sqlite3.connect("1994_results.db")
cursor = connection.cursor()
query = 'INSERT INTO results(medal, athlete) VALUES(?, ?)'

for tr in table.xpath('tr'):
    medal = tr.xpath('td/b/text()').extract()[0]
    athlete = tr.xpath('td/a/text()').extract()[0]
    cursor.execute(query, (medal, athlete)) 
    connection.commit()

# %% [markdown]
# The data is now persisted in a file-based database that you can query. Verify that all works by creating a new connection and querying the database.
#
# Update the _wikipedia_ project and spider to use some of these techniques to persist data. Next, try parsing all the files in the _html_ directory instead of just one and persist all results. Do you think you can parse other information as well?
#
# Try parsing the height and the results from all the other athletes, not just the top three places.

# %%
import scrapy
import os

# Directly using the new path provided
file_path = r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1998_World_Junior_Championships_in_Athletics_–_Men's_high_jump"

try:
    with open(file_path, 'r', encoding='utf-8') as _f:
        url_data = _f.read()

    # Since this is a local file, using a placeholder URL in the response object
    response = scrapy.http.TextResponse(url='file://' + file_path, body=url_data.encode('utf-8'), encoding='utf-8')
    print("File loaded successfully.")
except FileNotFoundError:
    print(f"File not found: {file_path}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# File loaded successfully.

# %%
# Assuming 'response' is your parsed HTML document
table = response.xpath('//table')[1].xpath('tbody')
for tr in response.xpath('//table/tr'):
    medal = tr.xpath('./td[1]/text()').get()
    athlete = tr.xpath('./td[2]/text()').get()
    height = tr.xpath('./td[3]/text()').get()
    result = tr.xpath('./td[4]/text()').get()
    # Process and save this data as needed

# %%
import json

# You can convert Python into JSON first, but there is no need if you use `json.dump()`
# as shown next
json_data = json.dumps(scrapped_data)

# Persist it in a file:
with open("1998_results.json", "w") as _f:
    # use dump() with the Python dictionary directly. 
    # the conversion is done on the fly
    json.dump(scrapped_data, _f)

# %%
import csv

column_names = ["Medal", "Athlete", "Height", "Result"]
rows = []  # This will be filled with data from the HTML parsing

# Assuming you've filled `rows` with the parsed data
with open("results.csv", "w", newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(column_names)
    writer.writerows(rows)

# %%
import os
import glob

def parse_html(file_path):
    # Implement parsing logic here
    pass

def save_to_csv(data, year):
    # Implement CSV writing logic here
    pass

def save_to_db(data, year):
    # Implement database saving logic here
    pass

def save_to_json(data, year):
    # Implement JSON writing logic here
    pass

# Example of iterating over HTML files and processing them
base_dir = r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping"
years = ['1992', '1994', '1996', '1998']

for year in years:
    html_files = glob.glob(os.path.join(base_dir, f"{year}_World_Junior_Championships_in_Athletics_–_Men's_high_jump"))
    for file_path in html_files:
        data = parse_html(file_path)
        # Example of deciding how to persist data based on some condition
        save_to_csv(data, year)
        save_to_db(data, year)
        save_to_json(data, year)

# %%
import os
import glob
import sqlite3
import csv
import json

# Define a function for parsing HTML files
def parse_html(file_path):
    # Dummy data - replace this with your actual parsing logic
    return [{'medal': 'Gold', 'athlete': 'Athlete Name', 'year': file_path.split('\\')[-1][:4]}]

# Function to save data to a CSV file
def save_to_csv(data, file_path):
    with open(file_path, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = data[0].keys()
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for row in data:
            writer.writerow(row)

# Function to save data to a SQLite database
def save_to_db(data, db_path):
    connection = sqlite3.connect(db_path)
    cursor = connection.cursor()
    for item in data:
        cursor.execute('INSERT INTO results (medal, athlete) VALUES (?, ?)', (item['medal'], item['athlete']))
    connection.commit()
    connection.close()

# Function to save data to a JSON file
def save_to_json(data, file_path):
    with open(file_path, 'w', encoding='utf-8') as jsonfile:
        json.dump(data, jsonfile, ensure_ascii=False, indent=4)

# Main processing logic
base_dir = r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping"

years = ['1992', '1994', '1996', '1998']
file_types = ['csv', 'db', 'json']

for year in years:
    # Construct file paths
    html_path = os.path.join(base_dir, f"{year}_World_Junior_Championships_in_Athletics_–_Men's_high_jump")
    paths = {
        'csv': os.path.join(base_dir, f"{year}_results.csv"),
        'db': os.path.join(base_dir, f"{year}_results.db"),
        'json': os.path.join(base_dir, f"{year}_results.json")
    }

    # Parse the HTML file
    data = parse_html(html_path)

    # Save to different formats
    save_to_csv(data, paths['csv'])
    save_to_db(data, paths['db'])
    save_to_json(data, paths['json'])

    print(f"Processed {year} data")
# Out:
# Processed 1992 data
# Processed 1994 data
# Processed 1996 data
# Processed 1998 data

# %%
import sqlite3

class SQLitePipeline:

    def open_spider(self, spider):
        self.connection = sqlite3.connect("results.db")
        self.c = self.connection.cursor()
        self.c.execute('''
            CREATE TABLE IF NOT EXISTS results (
                id INTEGER PRIMARY KEY,
                rank TEXT,
                athlete TEXT,
                height TEXT,
                result TEXT
            )
        ''')
        self.connection.commit()

    def close_spider(self, spider):
        self.connection.close()

    def process_item(self, item, spider):
        self.c.execute('''
            INSERT INTO results (rank, athlete, height, result) VALUES (?, ?, ?, ?)
        ''', (item['rank'], item['athlete'], item['height'], item['result']))
        self.connection.commit()
        return item

# %%
ITEM_PIPELINES = {
    'yourprojectname.pipelines.SQLitePipeline': 300,
}

FEEDS = {
    'results.json': {
        'format': 'json',
        'encoding': 'utf8',
        'store_empty': False,
        'item_export_kwargs': {
           'export_empty_fields': True,
        },
    },
    'results.csv': {
        'format': 'csv',
        'encoding': 'utf8',
        'store_empty': False,
    },
}

# %%
import scrapy
import sqlite3
import csv

class ResultsSpider(scrapy.Spider):
    name = "results"
    start_urls = ["file:///path/to/your/html/1992_World_Junior_Championships_in_Athletics_–_Men's_high_jump.html"]  # Use file URI scheme

    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        # Open a CSV file for writing
        self.csvfile = open("1992_results.csv", "w", newline='', encoding='utf-8')
        self.csvwriter = csv.writer(self.csvfile)
        # Write the header row
        self.csvwriter.writerow(["Medal", "Athlete", "Height", "Result"])
        
        # Connect to the database
        self.connection = sqlite3.connect("1992_results.db")
        self.cursor = self.connection.cursor()
        # Ensure the table exists
        self.cursor.execute('''
            CREATE TABLE IF NOT EXISTS results (
                id INTEGER PRIMARY KEY,
                medal TEXT,
                athlete TEXT,
                height TEXT,
                result TEXT
            )
        ''')

    def parse(self, response):
        # Iterate through each row in the table
        for tr in response.xpath('//tr[position()>1]'):  # Skipping the header row
            medal = tr.xpath('td[1]/text()').get()
            athlete = tr.xpath('td[2]/text()').get()
            height = tr.xpath('td[3]/text()').get()  # Update these based on actual HTML structure
            result = tr.xpath('td[4]/text()').get()

            # Write to CSV
            self.csvwriter.writerow([medal, athlete, height, result])

            # Insert into the database
            self.cursor.execute('INSERT INTO results (medal, athlete, height, result) VALUES (?, ?, ?, ?)', (medal, athlete, height, result))
        
        # Commit the database transaction
        self.connection.commit()

    def closed(self, reason):
        # Close the CSV file and database connection when the spider is closed
        self.csvfile.close()
        self.connection.close()

# %%
import scrapy
import os

# List of file paths
file_paths = [
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1992_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1994_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1996_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1998_World_Junior_Championships_in_Athletics_–_Men's_high_jump"
]

for file_path in file_paths:
    try:
        with open(file_path, 'r', encoding='utf-8') as _f:
            url_data = _f.read()

        # Since this is a local file, using a placeholder URL in the response object
        response = scrapy.http.TextResponse(url='file://' + file_path, body=url_data.encode('utf-8'), encoding='utf-8')
        print(f"File loaded successfully: {file_path}")
        
        # Ensure that the data extraction logic is within the loop
        # Adjust the index of the table if needed
        table = response.xpath('//table').xpath('tbody')  # Adjusted for simplification
        for tr in table.xpath('tr'):
            medal = tr.xpath('td/b/text()').get()
            athlete = tr.xpath('td/a/text()').get()
            print(medal, athlete)

    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except Exception as e:
        print(f"An error occurred with {file_path}: {e}")
# Out:
# File loaded successfully: C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1992_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# None None
# None None
# None None
# None men
# None men
# None men
# None men
# None men
# None women
# None men
# None men
# None women
# None men
# None men
# None men
# None men
# None men
# None women
# None men
# None None
# None men
# None men
# None men
# None men
# None men
# None men
# None men
# None men
# None None
# None women
# None men
# None None
# Gold Steve Smith
# Silver Tim Forsyth
# Bronze Takahiro Kimino
# None None
# 2.37 Steve Smith
# 2.31 Tim Forsyth
# 2.29 Takahiro Kimino
# 2.23 Kim Tae Young
# 2.20 Sergey Klyugin
# 2.20 Kristofer Lamos
# 2.17 Tomáš Janků
# 2.17 Coenraad Roux
# 2.17 Clayton Pugh
# 2.14 Xu Xiaodong
# 2.14 Sven Ootjers
# 2.14 Mirko Zanotti
# 2.14 Clifford van Reed
# 2.10 Dejan Miloševic
# 2.10 Hugo Muñoz
# 2.05 Stanley Osuide
# 2.05 Kostas Liapis
# 2.05 Kim Tae-hoi
# 2.00 Antoine Burke
# None None
# 2.16 Tim Forsyth
# 2.16 Takahiro Kimino
# 2.16 Xu Xiaodong
# 2.16 Clifford van Reed
# 2.16 Sven Ootjers
# 2.13 Stanley Osuide
# 2.13 Kristofer Lamos
# 2.13 Antoine Burke
# 2.13 Coenraad Roux
# 2.13 Kim Tae-hoi
# 2.13 Dejan Miloševic
# 2.13 Kostas Liapis
# 2.13 Hugo Muñoz
# 2.05 Giorgio Florindi
# 2.05 Oskari Frösén
# 2.00 Ignacio Pérez
# None None
# 2.16 Sergey Klyugin
# 2.16 Steve Smith
# 2.16 Kim Tae Young
# 2.16 Clayton Pugh
# 2.13 Mirko Zanotti
# 2.13 Tomáš Janků
# 2.10 Jochen Schmälzle
# 2.10 Olivier Paroz
# 2.10 Neophytos Kalogerou
# 2.10 Erik Mueller
# 2.10 Niki Grundner
# 2.10 Enrique Berruezo
# 2.05 Erik Nys
# 2.05 Toshihiro Koyama
# 2.05 Primoz Moljk
# 2.00 Andrés Leal
# None None
# None None
# None None
# File loaded successfully: C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1994_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# None None
# None None
# None None
# None men
# None men
# None men
# None men
# None men
# None women
# None men
# None men
# None women
# None men
# None men
# None men
# None men
# None men
# None women
# None men
# None None
# None men
# None None
# None men
# None men
# None men
# None men
# None men
# None men
# None men
# None men
# None None
# None women
# None men
# None None
# Gold Jagan Hames
# Silver Antoine Burke
# Bronze Mika Polku
# None None
# 2.23 Jagan Hames
# 2.20 Antoine Burke
# 2.20 Mika Polku
# 2.20 Attila Zsivoczky
# 2.15 Roland Stark
# 2.15 Oskari Frösén
# 2.10 Shunichi Kobayashi
# 2.10 Stefan Holm
# 2.10 Tomohiro Nomura
# 2.10 Henry Patterson
# 2.10 Bjørn Olsson
# 2.05 Stuart Ohrland
# None None
# 2.15 Antoine Burke
# 2.15 Oskari Frösén
# 2.15 Stuart Ohrland
# 2.15 Shunichi Kobayashi
# 2.10 Marcel Marie-Anne
# 2.10 Yoval Bukchin
# 2.10 Jordi Rofes
# 2.10 Michal Majchrowicz
# 2.10 Ola Carlsson
# 2.05 Jarrad Pozzi
# 2.00 Oleg Sklyar
# 2.00 Jeremy Fischer
# 2.00 Kang Myung-Soo
# 1.90 Esteve Martin
# NH Stephen Woodley
# None None
# 2.15 Jagan Hames
# 2.15 Mika Polku
# 2.15 Roland Stark
# 2.15 Attila Zsivoczky
# 2.15 Tomohiro Nomura
# 2.15 Bjørn Olsson
# 2.15 Stefan Holm
# 2.15 Henry Patterson
# 2.10 Yevgeniy Stekolshchikov
# 2.05 Moise Siba
# 2.05 James Brierley
# 2.05 Glenn Howard
# 2.00 Daniel Talam
# 2.00 Younès Moudrik
# 1.95 Rodolfo Moog
# 1.95 Olubunmi Robin-Coker
# None None
# None None
# None None
# File loaded successfully: C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1996_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# None None
# None None
# None None
# None men
# None men
# None men
# None men
# None men
# None women
# None men
# None men
# None women
# None men
# None men
# None men
# None men
# None men
# None women
# None men
# None None
# None men
# None men
# None men
# None men
# None men
# None men
# None men
# None men
# None None
# None women
# None men
# None None
# Gold Mark Boswell
# Silver Svatoslav Ton
# Silver Ben Challenger
# None None
# 2.24 Mark Boswell
# 2.21 Svatoslav Ton
# 2.21 Ben Challenger
# 2.18 Dave Furman
# 2.18 Toni Huikuri
# 2.18 Dejan Vreljakovic
# 2.15 James Brierley
# 2.15 Roman Fricke
# 2.15 François Potgieter
# 2.10 Yannick Tregaro
# 2.10 Tivadar Kovács
# 2.05 Noriyasu Arai
# None None
# 2.14 Svatoslav Ton
# 2.14 Toni Huikuri
# 2.14 James Brierley
# 2.14 Noriyasu Arai
# 2.14 Yannick Tregaro
# 2.14 Dejan Vreljakovic
# 2.10 Alfredo Deza
# 2.10 Vagner Principe
# 2.10 Alberto Juantorena Jr.
# 2.10 Marcin Kaczocha
# 2.05 Andrey Krasulya
# 2.05 David Larsen
# 2.00 Ronald Garlett
# 2.00 Oleg Prokopov
# 2.00 Felipe Apablaza
# 2.00 Luis Soto Caballero
# NH Zoltán Akacz
# None None
# 2.14 Mark Boswell
# 2.14 Ben Challenger
# 2.14 Roman Fricke
# 2.14 Tivadar Kovács
# 2.14 Dave Furman
# 2.14 François Potgieter
# 2.10 Sauli Niemi
# 2.10 Katsuyoshi Miyamichi
# 2.10 Marat Rakipov
# 2.10 Adi Mordel
# 2.10 Fabrício Romero
# 2.05 Abderahmane Hammad
# 2.05 Luke Temme
# 2.05 Aleksey Lesnichiy
# 2.00 Ha Chung-Soo
# 2.00 Dejan Dokleja
# NH Fawzi Warsame
# None None
# None None
# None None
# File loaded successfully: C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1998_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# None None
# None None
# None None
# None men
# None men
# None men
# None men
# None men
# None women
# None men
# None men
# None women
# None men
# None men
# None men
# None men
# None men
# None women
# None men
# None None
# None men
# None men
# None men
# None men
# None men
# None men
# None men
# None men
# None None
# None women
# None men
# None None
# Gold Alfredo Deza
# Silver Yin Xueli
# Bronze Aleksandr Veryutin
# None None
# 2.21 Alfredo Deza
# 2.21 Yin Xueli
# 2.21 Aleksandr Veryutin
# 2.21 Mike Ponikvar
# 2.18 Yaroslav Rybakov
# 2.15 Pawel Mankiewicz
# 2.15 Naoyuki Daigo
# 2.10 Ronald Garlett
# 2.10 Martin Lloyd
# 2.10 Casper Labuschagne
# 2.10 Nikolay Korostelyov
# 2.10 Einar Karl Hjartarson
# 2.10 Vusumzi Mtshatseni
# 2.10 James Carr
# None None
# 2.18 Nikolay Korostelyov
# 2.18 Mike Ponikvar
# 2.14 Vusumzi Mtshatseni
# 2.14 James Carr
# 2.14 Alfredo Deza
# 2.10 Aleksey Gordienko
# 2.10 Kim Jin-Soo
# 2.10 Andrei Mikhalkovich
# 2.10 Jérome Tourre
# 2.10 Marko Aleksejev
# 2.05 Ed Willers
# 2.05 Rožle Prezelj
# 2.05 Darrel Muzyczka
# 2.05 Paweł Gulcz
# 1.95 Kabelo Mmono
# None None
# 2.18 Naoyuki Daigo
# 2.18 Pawel Mankiewicz
# 2.18 Einar Karl Hjartarson
# 2.14 Aleksandr Veryutin
# 2.14 Yin Xueli
# 2.14 Ronald Garlett
# 2.14 Martin Lloyd
# 2.14 Casper Labuschagne
# 2.14 Yaroslav Rybakov
# 2.10 Hannes Zumsande
# 2.10 Lamar Johnson
# 2.05 Tarmo Kobin
# 2.05 Grégory Gabella
# 2.05 Randy Cheddesingh
# 2.00 Sergei Seipuk
# None None
# None None
# None None

# %%
import scrapy
import os

# List of file paths
file_paths = [
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1992_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1994_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1996_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1998_World_Junior_Championships_in_Athletics_–_Men's_high_jump"
]

for file_path in file_paths:
    try:
        with open(file_path, 'r', encoding='utf-8') as _f:
            url_data = _f.read()

        # Since this is a local file, using a placeholder URL in the response object
        response = scrapy.http.TextResponse(url='file://' + file_path, body=url_data.encode('utf-8'), encoding='utf-8')
        print(f"File loaded successfully: {file_path}")
        
        # Extract data from the table
        for tr in response.xpath('//table//tr'):
            medal = tr.xpath('./td[1]/b/text()').get() or tr.xpath('./td[1]/text()').get()
            athlete = tr.xpath('./td[2]/a/text()').get() or tr.xpath('./td[2]/text()').get()
            nationality = tr.xpath('./td[3]/img/@alt').get() or tr.xpath('./td[3]/text()').get()
            result = tr.xpath('./td[4]/text()').get() or tr.xpath('./td[4]/text()').get()

            if medal and athlete:  # Ensure variables are not None
                print(medal, athlete, nationality, result)
        
    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except Exception as e:
        print(f"An error occurred with {file_path}: {e}")
# Out:
# File loaded successfully: C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1992_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# Gold Steve Smith None None
# Silver Tim Forsyth None None
# Bronze Takahiro Kimino None None
# 4 Kim Tae Young None None
# 5 Sergey Klyugin None None
# 5 Kristofer Lamos None None
# 7 Tomáš Janků None None
# 8 Coenraad Roux None None
# 9 Clayton Pugh None None
# 10 Xu Xiaodong None None
# 10 Sven Ootjers None None
# 12 Mirko Zanotti None None
# 13 Clifford van Reed None None
# 14 Dejan Miloševic None None
# 15 Hugo Muñoz None None
# 16 Stanley Osuide None None
# 16 Kostas Liapis None None
# 16 Kim Tae-hoi None None
# 19 Antoine Burke None None
# 1 Tim Forsyth None None
# 1 Takahiro Kimino None None
# 3 Xu Xiaodong None None
# 3 Clifford van Reed None None
# 5 Sven Ootjers None None
# 6 Stanley Osuide None None
# 6 Kristofer Lamos None None
# 6 Antoine Burke None None
# 6 Coenraad Roux None None
# 10 Kim Tae-hoi None None
# 11 Dejan Miloševic None None
# 12 Kostas Liapis None None
# 13 Hugo Muñoz None None
# 14 Giorgio Florindi None None
# 15 Oskari Frösén None None
# 16 Ignacio Pérez None None
# 1 Sergey Klyugin None None
# 1 Steve Smith None None
# 1 Kim Tae Young None None
# 4 Clayton Pugh None None
# 5 Mirko Zanotti None None
# 5 Tomáš Janků None None
# 7 Jochen Schmälzle None None
# 7 Olivier Paroz None None
# 9 Neophytos Kalogerou None None
# 10 Erik Mueller None None
# 11 Niki Grundner None None
# 12 Enrique Berruezo None None
# 13 Erik Nys None None
# 13 Toshihiro Koyama None None
# 15 Primoz Moljk None None
# 16 Andrés Leal None None
# File loaded successfully: C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1994_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# Gold Jagan Hames None None
# Silver Antoine Burke None None
# Bronze Mika Polku None None
# 4 Attila Zsivoczky None None
# 5 Roland Stark None None
# 6 Oskari Frösén None None
# 7 Shunichi Kobayashi None None
# 7 Stefan Holm None None
# 9 Tomohiro Nomura None None
# 10 Henry Patterson None None
# 11 Bjørn Olsson None None
# 12 Stuart Ohrland None None
# 1 Antoine Burke None None
# 2 Oskari Frösén None None
# 3 Stuart Ohrland None None
# 4 Shunichi Kobayashi None None
# 5 Marcel Marie-Anne None None
# 5 Yoval Bukchin None None
# 7 Jordi Rofes None None
# 8 Michal Majchrowicz None None
# 9 Ola Carlsson None None
# 10 Jarrad Pozzi None None
# 11 Oleg Sklyar None None
# 12 Jeremy Fischer None None
# 13 Kang Myung-Soo None None
# 14 Esteve Martin None None
# 1 Jagan Hames None None
# 1 Mika Polku None None
# 1 Roland Stark None None
# 1 Attila Zsivoczky None None
# 5 Tomohiro Nomura None None
# 6 Bjørn Olsson None None
# 6 Stefan Holm None None
# 6 Henry Patterson None None
# 9 Yevgeniy Stekolshchikov None None
# 10 Moise Siba None None
# 11 James Brierley None None
# 11 Glenn Howard None None
# 13 Daniel Talam None None
# 14 Younès Moudrik None None
# 15 Rodolfo Moog None None
# 16 Olubunmi Robin-Coker None None
# File loaded successfully: C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1996_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# Gold Mark Boswell None None
# Silver Svatoslav Ton None None
# Silver Ben Challenger None None
# 4 Dave Furman None None
# 5 Toni Huikuri None None
# 6 Dejan Vreljakovic None None
# 7 James Brierley None None
# 7 Roman Fricke None None
# 9 François Potgieter None None
# 10 Yannick Tregaro None None
# 11 Tivadar Kovács None None
# 12 Noriyasu Arai None None
# 1 Svatoslav Ton None None
# 1 Toni Huikuri None None
# 1 James Brierley None None
# 1 Noriyasu Arai None None
# 5 Yannick Tregaro None None
# 5 Dejan Vreljakovic None None
# 7 Alfredo Deza None None
# 8 Vagner Principe None None
# 9 Alberto Juantorena Jr. None None
# 10 Marcin Kaczocha None None
# 11 Andrey Krasulya None None
# 12 David Larsen None None
# 13 Ronald Garlett None None
# 13 Oleg Prokopov None None
# 15 Felipe Apablaza None None
# 16 Luis Soto Caballero None None
# 1 Mark Boswell None None
# 1 Ben Challenger None None
# 1 Roman Fricke None None
# 1 Tivadar Kovács None None
# 1 Dave Furman None None
# 6 François Potgieter None None
# 7 Sauli Niemi None None
# 7 Katsuyoshi Miyamichi None None
# 9 Marat Rakipov None None
# 10 Adi Mordel None None
# 11 Fabrício Romero None None
# 12 Abderahmane Hammad None None
# 12 Luke Temme None None
# 14 Aleksey Lesnichiy None None
# 15 Ha Chung-Soo None None
# 16 Dejan Dokleja None None
# File loaded successfully: C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1998_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# Gold Alfredo Deza None None
# Silver Yin Xueli None None
# Bronze Aleksandr Veryutin None None
# 4 Mike Ponikvar None None
# 5 Yaroslav Rybakov None None
# 6 Pawel Mankiewicz None None
# 7 Naoyuki Daigo None None
# 8 Ronald Garlett None None
# 8 Martin Lloyd None None
# 8 Casper Labuschagne None None
# 8 Nikolay Korostelyov None None
# 12 Einar Karl Hjartarson None None
# 12 Vusumzi Mtshatseni None None
# 14 James Carr None None
# 1 Nikolay Korostelyov None None
# 2 Mike Ponikvar None None
# 3 Vusumzi Mtshatseni None None
# 3 James Carr None None
# 5 Alfredo Deza None None
# 6 Aleksey Gordienko None None
# 7 Kim Jin-Soo None None
# 8 Andrei Mikhalkovich None None
# 8 Jérome Tourre None None
# 10 Marko Aleksejev None None
# 11 Ed Willers None None
# 11 Rožle Prezelj None None
# 13 Darrel Muzyczka None None
# 13 Paweł Gulcz None None
# 15 Kabelo Mmono None None
# 1 Naoyuki Daigo None None
# 2 Pawel Mankiewicz None None
# 3 Einar Karl Hjartarson None None
# 4 Aleksandr Veryutin None None
# 4 Yin Xueli None None
# 6 Ronald Garlett None None
# 7 Martin Lloyd None None
# 7 Casper Labuschagne None None
# 7 Yaroslav Rybakov None None
# 10 Hannes Zumsande None None
# 11 Lamar Johnson None None
# 12 Tarmo Kobin None None
# 13 Grégory Gabella None None
# 14 Randy Cheddesingh None None
# 15 Sergei Seipuk None None
# c:\Users\oscar\AppData\Local\Programs\Python\Python312\Lib\site-packages\scrapy\selector\unified.py:82: UserWarning: Selector got both text and root, root is being ignored.
#   super().__init__(text=text, type=st, root=root, **kwargs)

# %%
import scrapy
import os

# List of file paths
file_paths = [
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1992_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1994_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1996_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1998_World_Junior_Championships_in_Athletics_–_Men's_high_jump"
]

for file_path in file_paths:
    try:
        with open(file_path, 'r', encoding='utf-8') as _f:
            url_data = _f.read()

        # Since this is a local file, using a placeholder URL in the response object
        response = scrapy.http.TextResponse(url='file://' + file_path, body=url_data.encode('utf-8'), encoding='utf-8')
        #print(f"File loaded successfully: {file_path}")
        
        # Extract data from the table
        for tr in response.xpath('//table//tr'):
            medal = tr.xpath('.//td[1]//img/@alt').extract_first(default='').split(',')[0]
            athlete = tr.xpath('./td[2]//a/text()').extract_first(default='N/A')
            nationality = tr.xpath('.//td[3]//a/text()').extract_first(default='N/A')
            result = tr.xpath('./td[4]/b/text() | ./td[4]/text()').extract_first(default='N/A').strip()

            if medal and athlete:  # Ensure variables are not None
                print(medal, athlete, nationality, result)
        
    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except Exception as e:
        print(f"An error occurred with {file_path}: {e}")
# Out:
# Athletics pictogram.svg N/A N/A N/A
# 1st place Steve Smith United Kingdom 2.37
# 2nd place Tim Forsyth Australia 2.31
# 3rd place Takahiro Kimino Japan 2.29
# Athletics pictogram.svg N/A N/A N/A
# 1st place Jagan Hames Australia 2.23
# 2nd place Antoine Burke Ireland 2.20
# 3rd place Mika Polku Finland 2.20
# Athletics pictogram.svg N/A N/A N/A
# 1st place Mark Boswell Canada 2.24
# 2nd place Svatoslav Ton Czech Republic 2.21
# 2nd place Ben Challenger United Kingdom 2.21
# Athletics pictogram.svg N/A N/A N/A
# 1st place Alfredo Deza Peru 2.21
# 2nd place Yin Xueli China 2.21
# 3rd place Aleksandr Veryutin Belarus 2.21

# %%
import scrapy

# List of file paths for demonstration purposes. Replace these paths with your actual file paths.
file_paths = [
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1992_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1994_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1996_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1998_World_Junior_Championships_in_Athletics_–_Men's_high_jump"
]

for file_path in file_paths:
    try:
        with open(file_path, 'r', encoding='utf-8') as _f:
            url_data = _f.read()

        # Since this is a local file, using a placeholder URL in the response object
        response = scrapy.http.TextResponse(url='file://' + file_path, body=url_data.encode('utf-8'), encoding='utf-8')
        print(f"File loaded successfully: {file_path}")
        
        # Extract data from the table
        for tr in response.xpath('//table//tr'):
            medal = tr.xpath('.//td[1]//img/@alt').extract_first(default='').split(',')[0]
            athlete = tr.xpath('./td[2]//a/text()').extract_first(default='N/A')
            nationality = tr.xpath('.//td[3]//a/text()').extract_first(default='N/A')
            result = tr.xpath('./td[4]/b/text() | ./td[4]/text()').extract_first(default='N/A').strip()

            # Skip rows where the athlete name is not available (assuming it's always present in a valid data row)
            if athlete == 'N/A':
                continue

            print(medal, athlete, nationality, result)
        
    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except Exception as e:
        print(f"An error occurred with {file_path}: {e}")
# Out:
# File loaded successfully: C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1992_World_Junior_Championships_in_Athletics_–_Men's_high_jump
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  Steve Smith N/A N/A
#  Tim Forsyth N/A N/A
#  Takahiro Kimino N/A N/A
# 1st place Steve Smith United Kingdom 2.37
# 2nd place Tim Forsyth Australia 2.31
# 3rd place Takahiro Kimino Japan 2.29
#  Kim Tae Young South Korea 2.23
#  Sergey Klyugin Commonwealth of Independent States 2.20
#  Kristofer Lamos Germany 2.20
#  Tomáš Janků Czechoslovakia 2.17
#  Coenraad Roux South Africa 2.17
#  Clayton Pugh Australia 2.17
#  Xu Xiaodong China 2.14
#  Sven Ootjers Netherlands 2.14
#  Mirko Zanotti Italy 2.14
#  Clifford van Reed United States 2.14
#  Dejan Miloševic Slovenia 2.10
#  Hugo Muñoz Peru 2.10
#  Stanley Osuide United Kingdom 2.05
#  Kostas Liapis Greece 2.05
#  Kim Tae-hoi South Korea 2.05
#  Antoine Burke Ireland 2.00
#  Tim Forsyth Australia 2.16
#  Takahiro Kimino Japan 2.16
#  Xu Xiaodong China 2.16
#  Clifford van Reed United States 2.16
#  Sven Ootjers Netherlands 2.16
#  Stanley Osuide United Kingdom 2.13
#  Kristofer Lamos Germany 2.13
#  Antoine Burke Ireland 2.13
#  Coenraad Roux South Africa 2.13
#  Kim Tae-hoi South Korea 2.13
#  Dejan Miloševic Slovenia 2.13
#  Kostas Liapis Greece 2.13
#  Hugo Muñoz Peru 2.13
#  Giorgio Florindi Italy 2.05
#  Oskari Frösén Finland 2.05
#  Ignacio Pérez Spain 2.00
#  Sergey Klyugin Commonwealth of Independent States 2.16
#  Steve Smith United Kingdom 2.16
#  Kim Tae Young South Korea 2.16
#  Clayton Pugh Australia 2.16
#  Mirko Zanotti Italy 2.13
#  Tomáš Janků Czechoslovakia 2.13
#  Jochen Schmälzle Germany 2.10
#  Olivier Paroz Switzerland 2.10
#  Neophytos Kalogerou Cyprus 2.10
#  Erik Mueller United States 2.10
#  Niki Grundner Austria 2.10
#  Enrique Berruezo Spain 2.10
#  Erik Nys Belgium 2.05
#  Toshihiro Koyama Japan 2.05
#  Primoz Moljk Slovenia 2.05
#  Andrés Leal Cuba 2.00
# File loaded successfully: C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1994_World_Junior_Championships_in_Athletics_–_Men's_high_jump
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  Jagan Hames N/A N/A
#  Antoine Burke N/A N/A
#  Mika Polku N/A N/A
# 1st place Jagan Hames Australia 2.23
# 2nd place Antoine Burke Ireland 2.20
# 3rd place Mika Polku Finland 2.20
#  Attila Zsivoczky Hungary 2.20
#  Roland Stark Germany 2.15
#  Oskari Frösén Finland 2.15
#  Shunichi Kobayashi Japan 2.10
#  Stefan Holm Sweden 2.10
#  Tomohiro Nomura Japan 2.10
#  Henry Patterson United States 2.10
#  Bjørn Olsson Norway 2.10
#  Stuart Ohrland United Kingdom 2.05
#  Antoine Burke Ireland 2.15
#  Oskari Frösén Finland 2.15
#  Stuart Ohrland United Kingdom 2.15
#  Shunichi Kobayashi Japan 2.15
#  Marcel Marie-Anne France 2.10
#  Yoval Bukchin Israel 2.10
#  Jordi Rofes Spain 2.10
#  Michal Majchrowicz Poland 2.10
#  Ola Carlsson Sweden 2.10
#  Jarrad Pozzi Australia 2.05
#  Oleg Sklyar Azerbaijan 2.00
#  Jeremy Fischer United States 2.00
#  Kang Myung-Soo South Korea 2.00
#  Esteve Martin Andorra 1.90
#  Stephen Woodley Bermuda NH
#  Jagan Hames Australia 2.15
#  Mika Polku Finland 2.15
#  Roland Stark Germany 2.15
#  Attila Zsivoczky Hungary 2.15
#  Tomohiro Nomura Japan 2.15
#  Bjørn Olsson Norway 2.15
#  Stefan Holm Sweden 2.15
#  Henry Patterson United States 2.15
#  Yevgeniy Stekolshchikov Russia 2.10
#  Moise Siba France 2.05
#  James Brierley United Kingdom 2.05
#  Glenn Howard New Zealand 2.05
#  Daniel Talam Kenya 2.00
#  Younès Moudrik Morocco 2.00
#  Rodolfo Moog Bolivia 1.95
#  Olubunmi Robin-Coker Sierra Leone 1.95
# File loaded successfully: C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1996_World_Junior_Championships_in_Athletics_–_Men's_high_jump
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  Mark Boswell N/A N/A
#  Svatoslav Ton N/A N/A
#  Ben Challenger N/A N/A
# 1st place Mark Boswell Canada 2.24
# 2nd place Svatoslav Ton Czech Republic 2.21
# 2nd place Ben Challenger United Kingdom 2.21
#  Dave Furman United States 2.18
#  Toni Huikuri Finland 2.18
#  Dejan Vreljakovic FR Yugoslavia 2.18
#  James Brierley United Kingdom 2.15
#  Roman Fricke Germany 2.15
#  François Potgieter South Africa 2.15
#  Yannick Tregaro Sweden 2.10
#  Tivadar Kovács Hungary 2.10
#  Noriyasu Arai Japan 2.05
#  Svatoslav Ton Czech Republic 2.14
#  Toni Huikuri Finland 2.14
#  James Brierley United Kingdom 2.14
#  Noriyasu Arai Japan 2.14
#  Yannick Tregaro Sweden 2.14
#  Dejan Vreljakovic FR Yugoslavia 2.14
#  Alfredo Deza Peru 2.10
#  Vagner Principe Brazil 2.10
#  Alberto Juantorena Jr. Cuba 2.10
#  Marcin Kaczocha Poland 2.10
#  Andrey Krasulya Ukraine 2.05
#  David Larsen United States 2.05
#  Ronald Garlett Australia 2.00
#  Oleg Prokopov Belarus 2.00
#  Felipe Apablaza Chile 2.00
#  Luis Soto Caballero Puerto Rico 2.00
#  Zoltán Akacz Hungary NH
#  Mark Boswell Canada 2.14
#  Ben Challenger United Kingdom 2.14
#  Roman Fricke Germany 2.14
#  Tivadar Kovács Hungary 2.14
#  Dave Furman United States 2.14
#  François Potgieter South Africa 2.14
#  Sauli Niemi Finland 2.10
#  Katsuyoshi Miyamichi Japan 2.10
#  Marat Rakipov Russia 2.10
#  Adi Mordel Israel 2.10
#  Fabrício Romero Brazil 2.10
#  Abderahmane Hammad Algeria 2.05
#  Luke Temme Australia 2.05
#  Aleksey Lesnichiy Belarus 2.05
#  Ha Chung-Soo South Korea 2.00
#  Dejan Dokleja Croatia 2.00
#  Fawzi Warsame Somalia NH
# File loaded successfully: C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1998_World_Junior_Championships_in_Athletics_–_Men's_high_jump
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  women N/A N/A
#  Alfredo Deza N/A N/A
#  Yin Xueli N/A N/A
#  Aleksandr Veryutin N/A N/A
# 1st place Alfredo Deza Peru 2.21
# 2nd place Yin Xueli China 2.21
# 3rd place Aleksandr Veryutin Belarus 2.21
#  Mike Ponikvar Canada 2.21
#  Yaroslav Rybakov Russia 2.18
#  Pawel Mankiewicz Poland 2.15
#  Naoyuki Daigo Japan 2.15
#  Ronald Garlett Australia 2.10
#  Martin Lloyd United Kingdom 2.10
#  Casper Labuschagne South Africa 2.10
#  Nikolay Korostelyov Russia 2.10
#  Einar Karl Hjartarson Iceland 2.10
#  Vusumzi Mtshatseni South Africa 2.10
#  James Carr United States 2.10
#  Nikolay Korostelyov Russia 2.18
#  Mike Ponikvar Canada 2.18
#  Vusumzi Mtshatseni South Africa 2.14
#  James Carr United States 2.14
#  Alfredo Deza Peru 2.14
#  Aleksey Gordienko Ukraine 2.10
#  Kim Jin-Soo South Korea 2.10
#  Andrei Mikhalkovich Belarus 2.10
#  Jérome Tourre France 2.10
#  Marko Aleksejev Estonia 2.10
#  Ed Willers United Kingdom 2.05
#  Rožle Prezelj Slovenia 2.05
#  Darrel Muzyczka Australia 2.05
#  Paweł Gulcz Poland 2.05
#  Kabelo Mmono Botswana 1.95
#  Naoyuki Daigo Japan 2.18
#  Pawel Mankiewicz Poland 2.18
#  Einar Karl Hjartarson Iceland 2.18
#  Aleksandr Veryutin Belarus 2.14
#  Yin Xueli China 2.14
#  Ronald Garlett Australia 2.14
#  Martin Lloyd United Kingdom 2.14
#  Casper Labuschagne South Africa 2.14
#  Yaroslav Rybakov Russia 2.14
#  Hannes Zumsande Germany 2.10
#  Lamar Johnson United States 2.10
#  Tarmo Kobin Estonia 2.05
#  Grégory Gabella France 2.05
#  Randy Cheddesingh Canada 2.05
#  Sergei Seipuk Lithuania 2.00

# %%
import scrapy

# List of file paths for demonstration purposes. Replace these paths with your actual file paths.
file_paths = [
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1992_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1994_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1996_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1998_World_Junior_Championships_in_Athletics_–_Men's_high_jump"
]

for file_path in file_paths:
    try:
        with open(file_path, 'r', encoding='utf-8') as _f:
            url_data = _f.read()

        response = scrapy.http.TextResponse(url='file://' + file_path, body=url_data.encode('utf-8'), encoding='utf-8')
        print(f"File loaded successfully: {file_path}")
        
        for tr in response.xpath('//table//tr'):
            # Check if the row looks like it contains data based on expected patterns
            if tr.xpath('.//td').extract_first(default='').strip():
                medal = tr.xpath('.//td[1]//img/@alt').extract_first(default='').split(',')[0]
                athlete = tr.xpath('./td[2]//a/text()').extract_first(default='N/A')
                nationality = tr.xpath('.//td[3]//a/text()').extract_first(default='N/A')
                result = tr.xpath('./td[4]/b/text() | ./td[4]/text()').extract_first(default='N/A').strip()

                # Skip rows where essential data is missing, indicating it's likely not a data row
                if athlete == 'N/A' or result == 'N/A':
                    continue

                print(medal, athlete, nationality, result)
        
    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except Exception as e:
        print(f"An error occurred with {file_path}: {e}")
# Out:
# File loaded successfully: C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1992_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# 1st place Steve Smith United Kingdom 2.37
# 2nd place Tim Forsyth Australia 2.31
# 3rd place Takahiro Kimino Japan 2.29
#  Kim Tae Young South Korea 2.23
#  Sergey Klyugin Commonwealth of Independent States 2.20
#  Kristofer Lamos Germany 2.20
#  Tomáš Janků Czechoslovakia 2.17
#  Coenraad Roux South Africa 2.17
#  Clayton Pugh Australia 2.17
#  Xu Xiaodong China 2.14
#  Sven Ootjers Netherlands 2.14
#  Mirko Zanotti Italy 2.14
#  Clifford van Reed United States 2.14
#  Dejan Miloševic Slovenia 2.10
#  Hugo Muñoz Peru 2.10
#  Stanley Osuide United Kingdom 2.05
#  Kostas Liapis Greece 2.05
#  Kim Tae-hoi South Korea 2.05
#  Antoine Burke Ireland 2.00
#  Tim Forsyth Australia 2.16
#  Takahiro Kimino Japan 2.16
#  Xu Xiaodong China 2.16
#  Clifford van Reed United States 2.16
#  Sven Ootjers Netherlands 2.16
#  Stanley Osuide United Kingdom 2.13
#  Kristofer Lamos Germany 2.13
#  Antoine Burke Ireland 2.13
#  Coenraad Roux South Africa 2.13
#  Kim Tae-hoi South Korea 2.13
#  Dejan Miloševic Slovenia 2.13
#  Kostas Liapis Greece 2.13
#  Hugo Muñoz Peru 2.13
#  Giorgio Florindi Italy 2.05
#  Oskari Frösén Finland 2.05
#  Ignacio Pérez Spain 2.00
#  Sergey Klyugin Commonwealth of Independent States 2.16
#  Steve Smith United Kingdom 2.16
#  Kim Tae Young South Korea 2.16
#  Clayton Pugh Australia 2.16
#  Mirko Zanotti Italy 2.13
#  Tomáš Janků Czechoslovakia 2.13
#  Jochen Schmälzle Germany 2.10
#  Olivier Paroz Switzerland 2.10
#  Neophytos Kalogerou Cyprus 2.10
#  Erik Mueller United States 2.10
#  Niki Grundner Austria 2.10
#  Enrique Berruezo Spain 2.10
#  Erik Nys Belgium 2.05
#  Toshihiro Koyama Japan 2.05
#  Primoz Moljk Slovenia 2.05
#  Andrés Leal Cuba 2.00
# File loaded successfully: C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1994_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# 1st place Jagan Hames Australia 2.23
# 2nd place Antoine Burke Ireland 2.20
# 3rd place Mika Polku Finland 2.20
#  Attila Zsivoczky Hungary 2.20
#  Roland Stark Germany 2.15
#  Oskari Frösén Finland 2.15
#  Shunichi Kobayashi Japan 2.10
#  Stefan Holm Sweden 2.10
#  Tomohiro Nomura Japan 2.10
#  Henry Patterson United States 2.10
#  Bjørn Olsson Norway 2.10
#  Stuart Ohrland United Kingdom 2.05
#  Antoine Burke Ireland 2.15
#  Oskari Frösén Finland 2.15
#  Stuart Ohrland United Kingdom 2.15
#  Shunichi Kobayashi Japan 2.15
#  Marcel Marie-Anne France 2.10
#  Yoval Bukchin Israel 2.10
#  Jordi Rofes Spain 2.10
#  Michal Majchrowicz Poland 2.10
#  Ola Carlsson Sweden 2.10
#  Jarrad Pozzi Australia 2.05
#  Oleg Sklyar Azerbaijan 2.00
#  Jeremy Fischer United States 2.00
#  Kang Myung-Soo South Korea 2.00
#  Esteve Martin Andorra 1.90
#  Stephen Woodley Bermuda NH
#  Jagan Hames Australia 2.15
#  Mika Polku Finland 2.15
#  Roland Stark Germany 2.15
#  Attila Zsivoczky Hungary 2.15
#  Tomohiro Nomura Japan 2.15
#  Bjørn Olsson Norway 2.15
#  Stefan Holm Sweden 2.15
#  Henry Patterson United States 2.15
#  Yevgeniy Stekolshchikov Russia 2.10
#  Moise Siba France 2.05
#  James Brierley United Kingdom 2.05
#  Glenn Howard New Zealand 2.05
#  Daniel Talam Kenya 2.00
#  Younès Moudrik Morocco 2.00
#  Rodolfo Moog Bolivia 1.95
#  Olubunmi Robin-Coker Sierra Leone 1.95
# File loaded successfully: C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1996_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# 1st place Mark Boswell Canada 2.24
# 2nd place Svatoslav Ton Czech Republic 2.21
# 2nd place Ben Challenger United Kingdom 2.21
#  Dave Furman United States 2.18
#  Toni Huikuri Finland 2.18
#  Dejan Vreljakovic FR Yugoslavia 2.18
#  James Brierley United Kingdom 2.15
#  Roman Fricke Germany 2.15
#  François Potgieter South Africa 2.15
#  Yannick Tregaro Sweden 2.10
#  Tivadar Kovács Hungary 2.10
#  Noriyasu Arai Japan 2.05
#  Svatoslav Ton Czech Republic 2.14
#  Toni Huikuri Finland 2.14
#  James Brierley United Kingdom 2.14
#  Noriyasu Arai Japan 2.14
#  Yannick Tregaro Sweden 2.14
#  Dejan Vreljakovic FR Yugoslavia 2.14
#  Alfredo Deza Peru 2.10
#  Vagner Principe Brazil 2.10
#  Alberto Juantorena Jr. Cuba 2.10
#  Marcin Kaczocha Poland 2.10
#  Andrey Krasulya Ukraine 2.05
#  David Larsen United States 2.05
#  Ronald Garlett Australia 2.00
#  Oleg Prokopov Belarus 2.00
#  Felipe Apablaza Chile 2.00
#  Luis Soto Caballero Puerto Rico 2.00
#  Zoltán Akacz Hungary NH
#  Mark Boswell Canada 2.14
#  Ben Challenger United Kingdom 2.14
#  Roman Fricke Germany 2.14
#  Tivadar Kovács Hungary 2.14
#  Dave Furman United States 2.14
#  François Potgieter South Africa 2.14
#  Sauli Niemi Finland 2.10
#  Katsuyoshi Miyamichi Japan 2.10
#  Marat Rakipov Russia 2.10
#  Adi Mordel Israel 2.10
#  Fabrício Romero Brazil 2.10
#  Abderahmane Hammad Algeria 2.05
#  Luke Temme Australia 2.05
#  Aleksey Lesnichiy Belarus 2.05
#  Ha Chung-Soo South Korea 2.00
#  Dejan Dokleja Croatia 2.00
#  Fawzi Warsame Somalia NH
# File loaded successfully: C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1998_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# 1st place Alfredo Deza Peru 2.21
# 2nd place Yin Xueli China 2.21
# 3rd place Aleksandr Veryutin Belarus 2.21
#  Mike Ponikvar Canada 2.21
#  Yaroslav Rybakov Russia 2.18
#  Pawel Mankiewicz Poland 2.15
#  Naoyuki Daigo Japan 2.15
#  Ronald Garlett Australia 2.10
#  Martin Lloyd United Kingdom 2.10
#  Casper Labuschagne South Africa 2.10
#  Nikolay Korostelyov Russia 2.10
#  Einar Karl Hjartarson Iceland 2.10
#  Vusumzi Mtshatseni South Africa 2.10
#  James Carr United States 2.10
#  Nikolay Korostelyov Russia 2.18
#  Mike Ponikvar Canada 2.18
#  Vusumzi Mtshatseni South Africa 2.14
#  James Carr United States 2.14
#  Alfredo Deza Peru 2.14
#  Aleksey Gordienko Ukraine 2.10
#  Kim Jin-Soo South Korea 2.10
#  Andrei Mikhalkovich Belarus 2.10
#  Jérome Tourre France 2.10
#  Marko Aleksejev Estonia 2.10
#  Ed Willers United Kingdom 2.05
#  Rožle Prezelj Slovenia 2.05
#  Darrel Muzyczka Australia 2.05
#  Paweł Gulcz Poland 2.05
#  Kabelo Mmono Botswana 1.95
#  Naoyuki Daigo Japan 2.18
#  Pawel Mankiewicz Poland 2.18
#  Einar Karl Hjartarson Iceland 2.18
#  Aleksandr Veryutin Belarus 2.14
#  Yin Xueli China 2.14
#  Ronald Garlett Australia 2.14
#  Martin Lloyd United Kingdom 2.14
#  Casper Labuschagne South Africa 2.14
#  Yaroslav Rybakov Russia 2.14
#  Hannes Zumsande Germany 2.10
#  Lamar Johnson United States 2.10
#  Tarmo Kobin Estonia 2.05
#  Grégory Gabella France 2.05
#  Randy Cheddesingh Canada 2.05
#  Sergei Seipuk Lithuania 2.00

# %%
import scrapy

# List of file paths for demonstration purposes. Replace these paths with your actual file paths.
file_paths = [
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1992_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1994_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1996_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1998_World_Junior_Championships_in_Athletics_–_Men's_high_jump"
]

for file_path in file_paths:
    try:
        with open(file_path, 'r', encoding='utf-8') as _f:
            url_data = _f.read()

        response = scrapy.http.TextResponse(url='file://' + file_path, body=url_data.encode('utf-8'), encoding='utf-8')
        print(f"File loaded successfully: {file_path}")
        
        # Initialize counter for athlete rank
        athlete_rank = 0
        
        for tr in response.xpath('//table//tr'):
            if tr.xpath('.//td').extract_first(default='').strip():
                medal = tr.xpath('.//td[1]//img/@alt').extract_first(default='').split(',')[0]
                athlete = tr.xpath('./td[2]//a/text()').extract_first(default='N/A')
                nationality = tr.xpath('.//td[3]//a/text()').extract_first(default='N/A')
                result = tr.xpath('./td[4]/b/text() | ./td[4]/text()').extract_first(default='N/A').strip()

                if athlete == 'N/A' or result == 'N/A':
                    continue
                
                # Increment athlete rank
                athlete_rank += 1
                
                # For non-medal positions, prepend rank to athlete's name
                if athlete_rank > 3:
                    position = f"{athlete_rank}th place"
                    print(position, athlete, nationality, result)
                else:
                    print(medal, athlete, nationality, result)
        
    except FileNotFoundError:
        print(f"File not found: {file_path}")
    except Exception as e:
        print(f"An error occurred with {file_path}: {e}")
# Out:
# File loaded successfully: C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1992_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# 1st place Steve Smith United Kingdom 2.37
# 2nd place Tim Forsyth Australia 2.31
# 3rd place Takahiro Kimino Japan 2.29
# 4th place Kim Tae Young South Korea 2.23
# 5th place Sergey Klyugin Commonwealth of Independent States 2.20
# 6th place Kristofer Lamos Germany 2.20
# 7th place Tomáš Janků Czechoslovakia 2.17
# 8th place Coenraad Roux South Africa 2.17
# 9th place Clayton Pugh Australia 2.17
# 10th place Xu Xiaodong China 2.14
# 11th place Sven Ootjers Netherlands 2.14
# 12th place Mirko Zanotti Italy 2.14
# 13th place Clifford van Reed United States 2.14
# 14th place Dejan Miloševic Slovenia 2.10
# 15th place Hugo Muñoz Peru 2.10
# 16th place Stanley Osuide United Kingdom 2.05
# 17th place Kostas Liapis Greece 2.05
# 18th place Kim Tae-hoi South Korea 2.05
# 19th place Antoine Burke Ireland 2.00
# 20th place Tim Forsyth Australia 2.16
# 21th place Takahiro Kimino Japan 2.16
# 22th place Xu Xiaodong China 2.16
# 23th place Clifford van Reed United States 2.16
# 24th place Sven Ootjers Netherlands 2.16
# 25th place Stanley Osuide United Kingdom 2.13
# 26th place Kristofer Lamos Germany 2.13
# 27th place Antoine Burke Ireland 2.13
# 28th place Coenraad Roux South Africa 2.13
# 29th place Kim Tae-hoi South Korea 2.13
# 30th place Dejan Miloševic Slovenia 2.13
# 31th place Kostas Liapis Greece 2.13
# 32th place Hugo Muñoz Peru 2.13
# 33th place Giorgio Florindi Italy 2.05
# 34th place Oskari Frösén Finland 2.05
# 35th place Ignacio Pérez Spain 2.00
# 36th place Sergey Klyugin Commonwealth of Independent States 2.16
# 37th place Steve Smith United Kingdom 2.16
# 38th place Kim Tae Young South Korea 2.16
# 39th place Clayton Pugh Australia 2.16
# 40th place Mirko Zanotti Italy 2.13
# 41th place Tomáš Janků Czechoslovakia 2.13
# 42th place Jochen Schmälzle Germany 2.10
# 43th place Olivier Paroz Switzerland 2.10
# 44th place Neophytos Kalogerou Cyprus 2.10
# 45th place Erik Mueller United States 2.10
# 46th place Niki Grundner Austria 2.10
# 47th place Enrique Berruezo Spain 2.10
# 48th place Erik Nys Belgium 2.05
# 49th place Toshihiro Koyama Japan 2.05
# 50th place Primoz Moljk Slovenia 2.05
# 51th place Andrés Leal Cuba 2.00
# File loaded successfully: C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1994_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# 1st place Jagan Hames Australia 2.23
# 2nd place Antoine Burke Ireland 2.20
# 3rd place Mika Polku Finland 2.20
# 4th place Attila Zsivoczky Hungary 2.20
# 5th place Roland Stark Germany 2.15
# 6th place Oskari Frösén Finland 2.15
# 7th place Shunichi Kobayashi Japan 2.10
# 8th place Stefan Holm Sweden 2.10
# 9th place Tomohiro Nomura Japan 2.10
# 10th place Henry Patterson United States 2.10
# 11th place Bjørn Olsson Norway 2.10
# 12th place Stuart Ohrland United Kingdom 2.05
# 13th place Antoine Burke Ireland 2.15
# 14th place Oskari Frösén Finland 2.15
# 15th place Stuart Ohrland United Kingdom 2.15
# 16th place Shunichi Kobayashi Japan 2.15
# 17th place Marcel Marie-Anne France 2.10
# 18th place Yoval Bukchin Israel 2.10
# 19th place Jordi Rofes Spain 2.10
# 20th place Michal Majchrowicz Poland 2.10
# 21th place Ola Carlsson Sweden 2.10
# 22th place Jarrad Pozzi Australia 2.05
# 23th place Oleg Sklyar Azerbaijan 2.00
# 24th place Jeremy Fischer United States 2.00
# 25th place Kang Myung-Soo South Korea 2.00
# 26th place Esteve Martin Andorra 1.90
# 27th place Stephen Woodley Bermuda NH
# 28th place Jagan Hames Australia 2.15
# 29th place Mika Polku Finland 2.15
# 30th place Roland Stark Germany 2.15
# 31th place Attila Zsivoczky Hungary 2.15
# 32th place Tomohiro Nomura Japan 2.15
# 33th place Bjørn Olsson Norway 2.15
# 34th place Stefan Holm Sweden 2.15
# 35th place Henry Patterson United States 2.15
# 36th place Yevgeniy Stekolshchikov Russia 2.10
# 37th place Moise Siba France 2.05
# 38th place James Brierley United Kingdom 2.05
# 39th place Glenn Howard New Zealand 2.05
# 40th place Daniel Talam Kenya 2.00
# 41th place Younès Moudrik Morocco 2.00
# 42th place Rodolfo Moog Bolivia 1.95
# 43th place Olubunmi Robin-Coker Sierra Leone 1.95
# File loaded successfully: C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1996_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# 1st place Mark Boswell Canada 2.24
# 2nd place Svatoslav Ton Czech Republic 2.21
# 2nd place Ben Challenger United Kingdom 2.21
# 4th place Dave Furman United States 2.18
# 5th place Toni Huikuri Finland 2.18
# 6th place Dejan Vreljakovic FR Yugoslavia 2.18
# 7th place James Brierley United Kingdom 2.15
# 8th place Roman Fricke Germany 2.15
# 9th place François Potgieter South Africa 2.15
# 10th place Yannick Tregaro Sweden 2.10
# 11th place Tivadar Kovács Hungary 2.10
# 12th place Noriyasu Arai Japan 2.05
# 13th place Svatoslav Ton Czech Republic 2.14
# 14th place Toni Huikuri Finland 2.14
# 15th place James Brierley United Kingdom 2.14
# 16th place Noriyasu Arai Japan 2.14
# 17th place Yannick Tregaro Sweden 2.14
# 18th place Dejan Vreljakovic FR Yugoslavia 2.14
# 19th place Alfredo Deza Peru 2.10
# 20th place Vagner Principe Brazil 2.10
# 21th place Alberto Juantorena Jr. Cuba 2.10
# 22th place Marcin Kaczocha Poland 2.10
# 23th place Andrey Krasulya Ukraine 2.05
# 24th place David Larsen United States 2.05
# 25th place Ronald Garlett Australia 2.00
# 26th place Oleg Prokopov Belarus 2.00
# 27th place Felipe Apablaza Chile 2.00
# 28th place Luis Soto Caballero Puerto Rico 2.00
# 29th place Zoltán Akacz Hungary NH
# 30th place Mark Boswell Canada 2.14
# 31th place Ben Challenger United Kingdom 2.14
# 32th place Roman Fricke Germany 2.14
# 33th place Tivadar Kovács Hungary 2.14
# 34th place Dave Furman United States 2.14
# 35th place François Potgieter South Africa 2.14
# 36th place Sauli Niemi Finland 2.10
# 37th place Katsuyoshi Miyamichi Japan 2.10
# 38th place Marat Rakipov Russia 2.10
# 39th place Adi Mordel Israel 2.10
# 40th place Fabrício Romero Brazil 2.10
# 41th place Abderahmane Hammad Algeria 2.05
# 42th place Luke Temme Australia 2.05
# 43th place Aleksey Lesnichiy Belarus 2.05
# 44th place Ha Chung-Soo South Korea 2.00
# 45th place Dejan Dokleja Croatia 2.00
# 46th place Fawzi Warsame Somalia NH
# File loaded successfully: C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1998_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# 1st place Alfredo Deza Peru 2.21
# 2nd place Yin Xueli China 2.21
# 3rd place Aleksandr Veryutin Belarus 2.21
# 4th place Mike Ponikvar Canada 2.21
# 5th place Yaroslav Rybakov Russia 2.18
# 6th place Pawel Mankiewicz Poland 2.15
# 7th place Naoyuki Daigo Japan 2.15
# 8th place Ronald Garlett Australia 2.10
# 9th place Martin Lloyd United Kingdom 2.10
# 10th place Casper Labuschagne South Africa 2.10
# 11th place Nikolay Korostelyov Russia 2.10
# 12th place Einar Karl Hjartarson Iceland 2.10
# 13th place Vusumzi Mtshatseni South Africa 2.10
# 14th place James Carr United States 2.10
# 15th place Nikolay Korostelyov Russia 2.18
# 16th place Mike Ponikvar Canada 2.18
# 17th place Vusumzi Mtshatseni South Africa 2.14
# 18th place James Carr United States 2.14
# 19th place Alfredo Deza Peru 2.14
# 20th place Aleksey Gordienko Ukraine 2.10
# 21th place Kim Jin-Soo South Korea 2.10
# 22th place Andrei Mikhalkovich Belarus 2.10
# 23th place Jérome Tourre France 2.10
# 24th place Marko Aleksejev Estonia 2.10
# 25th place Ed Willers United Kingdom 2.05
# 26th place Rožle Prezelj Slovenia 2.05
# 27th place Darrel Muzyczka Australia 2.05
# 28th place Paweł Gulcz Poland 2.05
# 29th place Kabelo Mmono Botswana 1.95
# 30th place Naoyuki Daigo Japan 2.18
# 31th place Pawel Mankiewicz Poland 2.18
# 32th place Einar Karl Hjartarson Iceland 2.18
# 33th place Aleksandr Veryutin Belarus 2.14
# 34th place Yin Xueli China 2.14
# 35th place Ronald Garlett Australia 2.14
# 36th place Martin Lloyd United Kingdom 2.14
# 37th place Casper Labuschagne South Africa 2.14
# 38th place Yaroslav Rybakov Russia 2.14
# 39th place Hannes Zumsande Germany 2.10
# 40th place Lamar Johnson United States 2.10
# 41th place Tarmo Kobin Estonia 2.05
# 42th place Grégory Gabella France 2.05
# 43th place Randy Cheddesingh Canada 2.05
# 44th place Sergei Seipuk Lithuania 2.00

# %%
import scrapy
import os

# Define your file paths here
file_paths = [
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1992_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1994_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1996_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1998_World_Junior_Championships_in_Athletics_–_Men's_high_jump"
]

def ordinal(n):
    return "%d%s" % (n, "th" if 4 <= n % 100 <= 20 else {1: "st", 2: "nd", 3: "rd"}.get(n % 10, "th"))

for file_path in file_paths:
    try:
        with open(file_path, 'r', encoding='utf-8') as _f:
            url_data = _f.read()

        response = scrapy.http.TextResponse(url='file://' + file_path, body=url_data.encode('utf-8'), encoding='utf-8')
        event_name = os.path.basename(file_path)
        print(f"{event_name}")
        
        athlete_rank = 0
        
        for tr in response.xpath('//table//tr[position()>1]'):
            # Extract and strip to remove leading/trailing whitespace
            athlete = tr.xpath('./td[2]//text()').get(default='').strip()
            nationality = tr.xpath('./td[3]//a/text()').get(default='').strip()
            result = tr.xpath('./td[4]/text()').get(default='').strip() or tr.xpath('./td[4]/b/text()').get(default='').strip()

            # Skip rows without meaningful athlete or result data
            if not athlete or athlete.lower() == "women" or not result:
                continue
            
            athlete_rank += 1
            
            position = ordinal(athlete_rank)
            
            # If nationality or result data is missing, print a placeholder message
            if not nationality or not result:
                print(f"{position} - {athlete} - Data not available")
            else:
                print(f"{position} - {athlete}, {nationality}, {result}")
        
    except FileNotFoundError:
        print(f"File not found for: {event_name}")
    except Exception as e:
        print(f"An error occurred with {event_name}: {e}")
# Out:
# 1992_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# 1st - Steve Smith, United Kingdom, 2.37
# 2nd - Tim Forsyth, Australia, 2.31
# 3rd - Takahiro Kimino, Japan, 2.29
# 4th - Kim Tae Young, South Korea, 2.23
# 5th - Sergey Klyugin, Commonwealth of Independent States, 2.20
# 6th - Kristofer Lamos, Germany, 2.20
# 7th - Tomáš Janků, Czechoslovakia, 2.17
# 8th - Coenraad Roux, South Africa, 2.17
# 9th - Clayton Pugh, Australia, 2.17
# 10th - Xu Xiaodong, China, 2.14
# 11th - Sven Ootjers, Netherlands, 2.14
# 12th - Mirko Zanotti, Italy, 2.14
# 13th - Clifford van Reed, United States, 2.14
# 14th - Dejan Miloševic, Slovenia, 2.10
# 15th - Hugo Muñoz, Peru, 2.10
# 16th - Stanley Osuide, United Kingdom, 2.05
# 17th - Kostas Liapis, Greece, 2.05
# 18th - Kim Tae-hoi, South Korea, 2.05
# 19th - Antoine Burke, Ireland, 2.00
# 20th - Tim Forsyth, Australia, 2.16
# 21st - Takahiro Kimino, Japan, 2.16
# 22nd - Xu Xiaodong, China, 2.16
# 23rd - Clifford van Reed, United States, 2.16
# 24th - Sven Ootjers, Netherlands, 2.16
# 25th - Stanley Osuide, United Kingdom, 2.13
# 26th - Kristofer Lamos, Germany, 2.13
# 27th - Antoine Burke, Ireland, 2.13
# 28th - Coenraad Roux, South Africa, 2.13
# 29th - Kim Tae-hoi, South Korea, 2.13
# 30th - Dejan Miloševic, Slovenia, 2.13
# 31st - Kostas Liapis, Greece, 2.13
# 32nd - Hugo Muñoz, Peru, 2.13
# 33rd - Giorgio Florindi, Italy, 2.05
# 34th - Oskari Frösén, Finland, 2.05
# 35th - Ignacio Pérez, Spain, 2.00
# 36th - Sergey Klyugin, Commonwealth of Independent States, 2.16
# 37th - Steve Smith, United Kingdom, 2.16
# 38th - Kim Tae Young, South Korea, 2.16
# 39th - Clayton Pugh, Australia, 2.16
# 40th - Mirko Zanotti, Italy, 2.13
# 41st - Tomáš Janků, Czechoslovakia, 2.13
# 42nd - Jochen Schmälzle, Germany, 2.10
# 43rd - Olivier Paroz, Switzerland, 2.10
# 44th - Neophytos Kalogerou, Cyprus, 2.10
# 45th - Erik Mueller, United States, 2.10
# 46th - Niki Grundner, Austria, 2.10
# 47th - Enrique Berruezo, Spain, 2.10
# 48th - Erik Nys, Belgium, 2.05
# 49th - Toshihiro Koyama, Japan, 2.05
# 50th - Primoz Moljk, Slovenia, 2.05
# 51st - Andrés Leal, Cuba, 2.00
# 1994_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# 1st - Jagan Hames, Australia, 2.23
# 2nd - Antoine Burke, Ireland, 2.20
# 3rd - Mika Polku, Finland, 2.20
# 4th - Attila Zsivoczky, Hungary, 2.20
# 5th - Roland Stark, Germany, 2.15
# 6th - Oskari Frösén, Finland, 2.15
# 7th - Shunichi Kobayashi, Japan, 2.10
# 8th - Stefan Holm, Sweden, 2.10
# 9th - Tomohiro Nomura, Japan, 2.10
# 10th - Henry Patterson, United States, 2.10
# 11th - Bjørn Olsson, Norway, 2.10
# 12th - Stuart Ohrland, United Kingdom, 2.05
# 13th - Antoine Burke, Ireland, 2.15
# 14th - Oskari Frösén, Finland, 2.15
# 15th - Stuart Ohrland, United Kingdom, 2.15
# 16th - Shunichi Kobayashi, Japan, 2.15
# 17th - Marcel Marie-Anne, France, 2.10
# 18th - Yoval Bukchin, Israel, 2.10
# 19th - Jordi Rofes, Spain, 2.10
# 20th - Michal Majchrowicz, Poland, 2.10
# 21st - Ola Carlsson, Sweden, 2.10
# 22nd - Jarrad Pozzi, Australia, 2.05
# 23rd - Oleg Sklyar, Azerbaijan, 2.00
# 24th - Jeremy Fischer, United States, 2.00
# 25th - Kang Myung-Soo, South Korea, 2.00
# 26th - Esteve Martin, Andorra, 1.90
# 27th - Stephen Woodley, Bermuda, NH
# 28th - Jagan Hames, Australia, 2.15
# 29th - Mika Polku, Finland, 2.15
# 30th - Roland Stark, Germany, 2.15
# 31st - Attila Zsivoczky, Hungary, 2.15
# 32nd - Tomohiro Nomura, Japan, 2.15
# 33rd - Bjørn Olsson, Norway, 2.15
# 34th - Stefan Holm, Sweden, 2.15
# 35th - Henry Patterson, United States, 2.15
# 36th - Yevgeniy Stekolshchikov, Russia, 2.10
# 37th - Moise Siba, France, 2.05
# 38th - James Brierley, United Kingdom, 2.05
# 39th - Glenn Howard, New Zealand, 2.05
# 40th - Daniel Talam, Kenya, 2.00
# 41st - Younès Moudrik, Morocco, 2.00
# 42nd - Rodolfo Moog, Bolivia, 1.95
# 43rd - Olubunmi Robin-Coker, Sierra Leone, 1.95
# 1996_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# 1st - Mark Boswell, Canada, 2.24
# 2nd - Svatoslav Ton, Czech Republic, 2.21
# 3rd - Ben Challenger, United Kingdom, 2.21
# 4th - Dave Furman, United States, 2.18
# 5th - Toni Huikuri, Finland, 2.18
# 6th - Dejan Vreljakovic, FR Yugoslavia, 2.18
# 7th - James Brierley, United Kingdom, 2.15
# 8th - Roman Fricke, Germany, 2.15
# 9th - François Potgieter, South Africa, 2.15
# 10th - Yannick Tregaro, Sweden, 2.10
# 11th - Tivadar Kovács, Hungary, 2.10
# 12th - Noriyasu Arai, Japan, 2.05
# 13th - Svatoslav Ton, Czech Republic, 2.14
# 14th - Toni Huikuri, Finland, 2.14
# 15th - James Brierley, United Kingdom, 2.14
# 16th - Noriyasu Arai, Japan, 2.14
# 17th - Yannick Tregaro, Sweden, 2.14
# 18th - Dejan Vreljakovic, FR Yugoslavia, 2.14
# 19th - Alfredo Deza, Peru, 2.10
# 20th - Vagner Principe, Brazil, 2.10
# 21st - Alberto Juantorena Jr., Cuba, 2.10
# 22nd - Marcin Kaczocha, Poland, 2.10
# 23rd - Andrey Krasulya, Ukraine, 2.05
# 24th - David Larsen, United States, 2.05
# 25th - Ronald Garlett, Australia, 2.00
# 26th - Oleg Prokopov, Belarus, 2.00
# 27th - Felipe Apablaza, Chile, 2.00
# 28th - Luis Soto Caballero, Puerto Rico, 2.00
# 29th - Zoltán Akacz, Hungary, NH
# 30th - Mark Boswell, Canada, 2.14
# 31st - Ben Challenger, United Kingdom, 2.14
# 32nd - Roman Fricke, Germany, 2.14
# 33rd - Tivadar Kovács, Hungary, 2.14
# 34th - Dave Furman, United States, 2.14
# 35th - François Potgieter, South Africa, 2.14
# 36th - Sauli Niemi, Finland, 2.10
# 37th - Katsuyoshi Miyamichi, Japan, 2.10
# 38th - Marat Rakipov, Russia, 2.10
# 39th - Adi Mordel, Israel, 2.10
# 40th - Fabrício Romero, Brazil, 2.10
# 41st - Abderahmane Hammad, Algeria, 2.05
# 42nd - Luke Temme, Australia, 2.05
# 43rd - Aleksey Lesnichiy, Belarus, 2.05
# 44th - Ha Chung-Soo, South Korea, 2.00
# 45th - Dejan Dokleja, Croatia, 2.00
# 46th - Fawzi Warsame, Somalia, NH
# 1998_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# 1st - Alfredo Deza, Peru, 2.21
# 2nd - Yin Xueli, China, 2.21
# 3rd - Aleksandr Veryutin, Belarus, 2.21
# 4th - Mike Ponikvar, Canada, 2.21
# 5th - Yaroslav Rybakov, Russia, 2.18
# 6th - Pawel Mankiewicz, Poland, 2.15
# 7th - Naoyuki Daigo, Japan, 2.15
# 8th - Ronald Garlett, Australia, 2.10
# 9th - Martin Lloyd, United Kingdom, 2.10
# 10th - Casper Labuschagne, South Africa, 2.10
# 11th - Nikolay Korostelyov, Russia, 2.10
# 12th - Einar Karl Hjartarson, Iceland, 2.10
# 13th - Vusumzi Mtshatseni, South Africa, 2.10
# 14th - James Carr, United States, 2.10
# 15th - Nikolay Korostelyov, Russia, 2.18
# 16th - Mike Ponikvar, Canada, 2.18
# 17th - Vusumzi Mtshatseni, South Africa, 2.14
# 18th - James Carr, United States, 2.14
# 19th - Alfredo Deza, Peru, 2.14
# 20th - Aleksey Gordienko, Ukraine, 2.10
# 21st - Kim Jin-Soo, South Korea, 2.10
# 22nd - Andrei Mikhalkovich, Belarus, 2.10
# 23rd - Jérome Tourre, France, 2.10
# 24th - Marko Aleksejev, Estonia, 2.10
# 25th - Ed Willers, United Kingdom, 2.05
# 26th - Rožle Prezelj, Slovenia, 2.05
# 27th - Darrel Muzyczka, Australia, 2.05
# 28th - Paweł Gulcz, Poland, 2.05
# 29th - Kabelo Mmono, Botswana, 1.95
# 30th - Naoyuki Daigo, Japan, 2.18
# 31st - Pawel Mankiewicz, Poland, 2.18
# 32nd - Einar Karl Hjartarson, Iceland, 2.18
# 33rd - Aleksandr Veryutin, Belarus, 2.14
# 34th - Yin Xueli, China, 2.14
# 35th - Ronald Garlett, Australia, 2.14
# 36th - Martin Lloyd, United Kingdom, 2.14
# 37th - Casper Labuschagne, South Africa, 2.14
# 38th - Yaroslav Rybakov, Russia, 2.14
# 39th - Hannes Zumsande, Germany, 2.10
# 40th - Lamar Johnson, United States, 2.10
# 41st - Tarmo Kobin, Estonia, 2.05
# 42nd - Grégory Gabella, France, 2.05
# 43rd - Randy Cheddesingh, Canada, 2.05
# 44th - Sergei Seipuk, Lithuania, 2.00

# %%
import scrapy
import os
import csv
import json
import sqlite3

# Define your file paths here
file_paths = [
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1992_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1994_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1996_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1998_World_Junior_Championships_in_Athletics_–_Men's_high_jump"
]

# Helper function for ordinal numbers
def ordinal(n):
    return "%d%s" % (n, "th" if 4 <= n % 100 <= 20 else {1: "st", 2: "nd", 3: "rd"}.get(n % 10, "th"))

# List to store all athlete data
athletes_data = []

for file_path in file_paths:
    try:
        with open(file_path, 'r', encoding='utf-8') as _f:
            url_data = _f.read()

        response = scrapy.http.TextResponse(url='file://' + file_path, body=url_data.encode('utf-8'), encoding='utf-8')
        event_name = os.path.basename(file_path)
        print(f"{event_name}")
        
        athlete_rank = 0
        
        for tr in response.xpath('//table//tr[position()>1]'):
            athlete = tr.xpath('./td[2]//text()').get(default='').strip()
            nationality = tr.xpath('./td[3]//a/text()').get(default='').strip()
            result = tr.xpath('./td[4]/text()').get(default='').strip() or tr.xpath('./td[4]/b/text()').get(default='').strip()

            if not athlete or athlete.lower() == "women" or not result:
                continue
            
            athlete_rank += 1
            position = ordinal(athlete_rank)
            
            athletes_data.append({
                "Position": position,
                "Athlete": athlete,
                "Nationality": nationality,
                "Result": result
            })
        
    except FileNotFoundError:
        print(f"File not found for: {event_name}")
    except Exception as e:
        print(f"An error occurred with {event_name}: {e}")

# Writing to CSV
csv_file = "allyearsdata.csv"
with open(csv_file, 'w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=["Position", "Athlete", "Nationality", "Result"])
    writer.writeheader()
    for data in athletes_data:
        writer.writerow(data)

# Writing to JSON
json_file = "allyearsdata.json"
with open(json_file, 'w', encoding='utf-8') as file:
    json.dump(athletes_data, file, ensure_ascii=False, indent=4)

# Writing to SQLite DB
db_file = "allyearsdata.db"
conn = sqlite3.connect(db_file)
c = conn.cursor()
c.execute('''CREATE TABLE IF NOT EXISTS athletes
             (Position TEXT, Athlete TEXT, Nationality TEXT, Result TEXT)''')
for data in athletes_data:
    c.execute("INSERT INTO athletes VALUES (:Position, :Athlete, :Nationality, :Result)", data)
conn.commit()
conn.close()

print("Data saved to CSV, JSON, and SQLite DB.")
# Out:
# 1992_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# 1994_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# 1996_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# 1998_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# Data saved to CSV, JSON, and SQLite DB.

# %%
import scrapy
import os
import csv
import json
import sqlite3

# Define your file paths here
file_paths = [
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1992_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1994_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1996_World_Junior_Championships_in_Athletics_–_Men's_high_jump",
    r"C:\Users\oscar\OneDrive\Oscar\Master_Data_Science_AI_Nuclio_School\Projects\Coursera_Webscrapping\1998_World_Junior_Championships_in_Athletics_–_Men's_high_jump"
]

def ordinal(n):
    """Helper function for ordinal numbers."""
    return "%d%s" % (n, "th" if 4 <= n % 100 <= 20 else {1: "st", 2: "nd", 3: "rd"}.get(n % 10, "th"))

# List to store all athlete data
athletes_data = []

for file_path in file_paths:
    try:
        with open(file_path, 'r', encoding='utf-8') as _f:
            url_data = _f.read()

        response = scrapy.http.TextResponse(url='file://' + file_path, body=url_data.encode('utf-8'), encoding='utf-8')
        event_name = os.path.basename(file_path)
        print(event_name)

        athlete_rank = 0
        for tr in response.xpath('//table//tr[position()>1]'):
            if athlete_rank >= 10:  # Stop after processing 10 athletes
                break

            athlete = tr.xpath('./td[2]//text()').get(default='').strip()
            nationality = tr.xpath('./td[3]//a/text()').get(default='').strip()
            result = tr.xpath('./td[4]/text()').get(default='').strip() or tr.xpath('./td[4]/b/text()').get(default='').strip()

            if not athlete or athlete.lower() == "women" or not result:
                continue

            athlete_rank += 1
            position = ordinal(athlete_rank)

            athletes_data.append({
                "Event": event_name,
                "Position": position,
                "Athlete": athlete,
                "Nationality": nationality,
                "Result": result
            })

    except FileNotFoundError:
        print(f"File not found for: {event_name}")
    except Exception as e:
        print(f"An error occurred with {event_name}: {e}")

# Writing to CSV
csv_file = "allyearsdata.csv"
with open(csv_file, 'w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=["Event", "Position", "Athlete", "Nationality", "Result"])
    writer.writeheader()
    for data in athletes_data:
        writer.writerow(data)

# Writing to JSON
json_file = "allyearsdata.json"
with open(json_file, 'w', encoding='utf-8') as file:
    json.dump(athletes_data, file, ensure_ascii=False, indent=4)

# Writing to SQLite DB
db_file = "allyearsdata.db"
conn = sqlite3.connect(db_file)
c = conn.cursor()
c.execute('''CREATE TABLE IF NOT EXISTS athletes
             (Event TEXT, Position TEXT, Athlete TEXT, Nationality TEXT, Result TEXT)''')
for data in athletes_data:
    c.execute("INSERT INTO athletes VALUES (:Event, :Position, :Athlete, :Nationality, :Result)", data)
conn.commit()
conn.close()

print("Data saved to CSV, JSON, and SQLite DB.")
# Out:
# 1992_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# 1994_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# 1996_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# 1998_World_Junior_Championships_in_Athletics_–_Men's_high_jump
# Data saved to CSV, JSON, and SQLite DB.
